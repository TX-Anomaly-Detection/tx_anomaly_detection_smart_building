# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv("Hanoi_CMH/Labels.csv")

# %%
df
# Out:
#      Scenario  Label
# 0           1    0.0
# 1           2    0.0
# 2           3    1.0
# 3           4    0.0
# 4           5    1.0
# ..        ...    ...
# 495       496    1.0
# 496       497    1.0
# 497       498    1.0
# 498       499    1.0
# 499       500    1.0
#
# [500 rows x 2 columns]

# %%
df[df["Label"]==1].head(10)
# Out:
#     Scenario  Label
# 2          3    1.0
# 4          5    1.0
# 5          6    1.0
# 6          7    1.0
# 7          8    1.0
# 9         10    1.0
# 10        11    1.0
# 11        12    1.0
# 12        13    1.0
# 13        14    1.0

# %% [markdown]
# # Scenario 5

# %%
df3 = pd.read_csv("Hanoi_CMH/Scenario-5/Demands/Node_21.csv")
df4 = pd.read_csv("Hanoi_CMH/Scenario-5/Flows/Link_22.csv")
df5 = pd.read_csv("Hanoi_CMH/Scenario-5/Labels.csv")
df6 = pd.read_csv("Hanoi_CMH/Scenario-5/Pressures/Node_21.csv")

# %%
def test(x):
    if x["Label"] == 1:
        return 1
    else:
        return 0

# %%
df3["Label"] = df5.apply(test, axis=1)
df4["Label"] = df5.apply(test, axis=1)
df6["Label"] = df5.apply(test, axis=1)

# %% [markdown]
# ## Some tests

# %%
df3["Timestamp"] = pd.to_datetime(df3["Timestamp"])
df4["Timestamp"] = pd.to_datetime(df4["Timestamp"])
df5["Timestamp"] = pd.to_datetime(df5["Timestamp"])
df6["Timestamp"] = pd.to_datetime(df6["Timestamp"])

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6, hue="Label")

# %%
df3_groupby = df3.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df4_groupby = df4.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df5_groupby = df5.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df6_groupby = df6.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()

# %%
df3_groupby.reset_index(inplace=True)
df4_groupby.reset_index(inplace=True)
df5_groupby.reset_index(inplace=True)
df6_groupby.reset_index(inplace=True)

# %%
def add_label(df):
    if df["Label"] > 0.5:
        return 1
    else:
        return 0

# %%
df3_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df4_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df6_groupby["Label"] = df5_groupby.apply(add_label, axis=1)

# %%
sns.lineplot(x="Timestamp", y="Value", data=df3_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df4_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %% [markdown]
# # Scenario 6

# %%
df3 = pd.read_csv("Hanoi_CMH/Scenario-6/Demands/Node_18.csv")
df4 = pd.read_csv("Hanoi_CMH/Scenario-6/Flows/Link_17.csv")
df5 = pd.read_csv("Hanoi_CMH/Scenario-6/Labels.csv")
df6 = pd.read_csv("Hanoi_CMH/Scenario-6/Pressures/Node_18.csv")

# %%
df3["Label"] = df5.apply(test, axis=1)
df4["Label"] = df5.apply(test, axis=1)
df6["Label"] = df5.apply(test, axis=1)

# %%
df3["Timestamp"] = pd.to_datetime(df3["Timestamp"])
df4["Timestamp"] = pd.to_datetime(df4["Timestamp"])
df5["Timestamp"] = pd.to_datetime(df5["Timestamp"])
df6["Timestamp"] = pd.to_datetime(df6["Timestamp"])

df3_groupby = df3.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df4_groupby = df4.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df5_groupby = df5.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df6_groupby = df6.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()

df3_groupby.reset_index(inplace=True)
df4_groupby.reset_index(inplace=True)
df5_groupby.reset_index(inplace=True)
df6_groupby.reset_index(inplace=True)

def add_label(df):
    if df["Label"] > 0.5:
        return 1
    else:
        return 0

df3_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df4_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df6_groupby["Label"] = df5_groupby.apply(add_label, axis=1)

# %%
sns.lineplot(x="Timestamp", y="Value", data=df3_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df4_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %% [markdown]
# # Scenario 7

# %%
df3 = pd.read_csv("Hanoi_CMH/Scenario-7/Demands/Node_14.csv")
df4 = pd.read_csv("Hanoi_CMH/Scenario-7/Flows/Link_14.csv")
df5 = pd.read_csv("Hanoi_CMH/Scenario-7/Labels.csv")
df6 = pd.read_csv("Hanoi_CMH/Scenario-7/Pressures/Node_14.csv")

# %%
df3["Label"] = df5.apply(test, axis=1)
df4["Label"] = df5.apply(test, axis=1)
df6["Label"] = df5.apply(test, axis=1)

# %%
df3["Timestamp"] = pd.to_datetime(df3["Timestamp"])
df4["Timestamp"] = pd.to_datetime(df4["Timestamp"])
df5["Timestamp"] = pd.to_datetime(df5["Timestamp"])
df6["Timestamp"] = pd.to_datetime(df6["Timestamp"])

df3_groupby = df3.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df4_groupby = df4.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df5_groupby = df5.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df6_groupby = df6.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()

df3_groupby.reset_index(inplace=True)
df4_groupby.reset_index(inplace=True)
df5_groupby.reset_index(inplace=True)
df6_groupby.reset_index(inplace=True)

def add_label(df):
    if df["Label"] > 0.5:
        return 1
    else:
        return 0

df3_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df4_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df6_groupby["Label"] = df5_groupby.apply(add_label, axis=1)

# %%
sns.lineplot(x="Timestamp", y="Value", data=df3_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df4_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %% [markdown]
# # Scenario 8

# %% [markdown]
# ## Leak at node 17

# %%
start_date = pd.to_datetime("2017-07-18 06:00:00")
end_date = pd.to_datetime("2017-09-19 04:00:00")
def test(x):
    if x["Label"] == 1 and x["Timestamp"]>=start_date and x["Timestamp"]<=end_date:
        return 1
    else:
        return 0

def add_label(df):
    if df["Label"] > 0.5 and df["Timestamp"]>=start_date and df["Timestamp"]<=end_date:
        return 1
    else:
        return 0

# %%
df3 = pd.read_csv("Hanoi_CMH/Scenario-8/Demands/Node_17.csv")
df4 = pd.read_csv("Hanoi_CMH/Scenario-8/Flows/Link_16.csv")
df5 = pd.read_csv("Hanoi_CMH/Scenario-8/Labels.csv")
df6 = pd.read_csv("Hanoi_CMH/Scenario-8/Pressures/Node_17.csv")

df3["Timestamp"] = pd.to_datetime(df3["Timestamp"])
df4["Timestamp"] = pd.to_datetime(df4["Timestamp"])
df5["Timestamp"] = pd.to_datetime(df5["Timestamp"])
df6["Timestamp"] = pd.to_datetime(df6["Timestamp"])

df3["Label"] = df5.apply(test, axis=1)
df4["Label"] = df5.apply(test, axis=1)
df6["Label"] = df5.apply(test, axis=1)

df3_groupby = df3.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df4_groupby = df4.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df5_groupby = df5.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df6_groupby = df6.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()

df3_groupby.reset_index(inplace=True)
df4_groupby.reset_index(inplace=True)
df5_groupby.reset_index(inplace=True)
df6_groupby.reset_index(inplace=True)

df3_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df4_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df6_groupby["Label"] = df5_groupby.apply(add_label, axis=1)

# %%
sns.lineplot(x="Timestamp", y="Value", data=df3_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df4_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %% [markdown]
# ## Leak at Node 21

# %%
start_date = pd.to_datetime("2017-08-16 14:00:00")
end_date = pd.to_datetime("2017-10-29 02:00:00")
def test(x):
    if x["Label"] == 1 and x["Timestamp"]>=start_date and x["Timestamp"]<=end_date:
        return 1
    else:
        return 0

def add_label(df):
    if df["Label"] > 0.5 and df["Timestamp"]>=start_date and df["Timestamp"]<=end_date:
        return 1
    else:
        return 0

# %%
df3 = pd.read_csv("Hanoi_CMH/Scenario-8/Demands/Node_21.csv")
df4 = pd.read_csv("Hanoi_CMH/Scenario-8/Flows/Link_21.csv")
df5 = pd.read_csv("Hanoi_CMH/Scenario-8/Labels.csv")
df6 = pd.read_csv("Hanoi_CMH/Scenario-8/Pressures/Node_21.csv")

df3["Timestamp"] = pd.to_datetime(df3["Timestamp"])
df4["Timestamp"] = pd.to_datetime(df4["Timestamp"])
df5["Timestamp"] = pd.to_datetime(df5["Timestamp"])
df6["Timestamp"] = pd.to_datetime(df6["Timestamp"])

df3["Label"] = df5.apply(test, axis=1)
df4["Label"] = df5.apply(test, axis=1)
df6["Label"] = df5.apply(test, axis=1)

df3_groupby = df3.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df4_groupby = df4.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df5_groupby = df5.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df6_groupby = df6.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()

df3_groupby.reset_index(inplace=True)
df4_groupby.reset_index(inplace=True)
df5_groupby.reset_index(inplace=True)
df6_groupby.reset_index(inplace=True)

df3_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df4_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df6_groupby["Label"] = df5_groupby.apply(add_label, axis=1)

# %%
sns.lineplot(x="Timestamp", y="Value", data=df3_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df4_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %% [markdown]
# # Scenario 10

# %% [markdown]
# ## Leak at Node 12

# %%
start_date = pd.to_datetime("2017-11-06 05:00:00")
end_date = pd.to_datetime("2017-11-11 19:00:00")
def test(x):
    if x["Label"] == 1 and x["Timestamp"]>=start_date and x["Timestamp"]<=end_date:
        return 1
    else:
        return 0

def add_label(df):
    if df["Label"] > 0.5 and df["Timestamp"]>=start_date and df["Timestamp"]<=end_date:
        return 1
    else:
        return 0

# %%
df3 = pd.read_csv("Hanoi_CMH/Scenario-10/Demands/Node_12.csv")
df4 = pd.read_csv("Hanoi_CMH/Scenario-10/Flows/Link_11.csv")
df5 = pd.read_csv("Hanoi_CMH/Scenario-10/Labels.csv")
df6 = pd.read_csv("Hanoi_CMH/Scenario-10/Pressures/Node_12.csv")

df3["Timestamp"] = pd.to_datetime(df3["Timestamp"])
df4["Timestamp"] = pd.to_datetime(df4["Timestamp"])
df5["Timestamp"] = pd.to_datetime(df5["Timestamp"])
df6["Timestamp"] = pd.to_datetime(df6["Timestamp"])

df3["Label"] = df5.apply(test, axis=1)
df4["Label"] = df5.apply(test, axis=1)
df6["Label"] = df5.apply(test, axis=1)

df3_groupby = df3.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df4_groupby = df4.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df5_groupby = df5.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df6_groupby = df6.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()

df3_groupby.reset_index(inplace=True)
df4_groupby.reset_index(inplace=True)
df5_groupby.reset_index(inplace=True)
df6_groupby.reset_index(inplace=True)

df3_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df4_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df6_groupby["Label"] = df5_groupby.apply(add_label, axis=1)

# %%
sns.lineplot(x="Timestamp", y="Value", data=df3_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df4_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %% [markdown]
# ## Leak at Node 28

# %%
start_date = pd.to_datetime("2017-05-22 13:30:00")
end_date = pd.to_datetime("2017-10-24 11:30:00")
def test(x):
    if x["Label"] == 1 and x["Timestamp"]>=start_date and x["Timestamp"]<=end_date:
        return 1
    else:
        return 0

def add_label(df):
    if df["Label"] > 0.5 and df["Timestamp"]>=start_date and df["Timestamp"]<=end_date:
        return 1
    else:
        return 0

# %%
df3 = pd.read_csv("Hanoi_CMH/Scenario-10/Demands/Node_28.csv")
df4 = pd.read_csv("Hanoi_CMH/Scenario-10/Flows/Link_30.csv")
df5 = pd.read_csv("Hanoi_CMH/Scenario-10/Labels.csv")
df6 = pd.read_csv("Hanoi_CMH/Scenario-10/Pressures/Node_28.csv")

df3["Timestamp"] = pd.to_datetime(df3["Timestamp"])
df4["Timestamp"] = pd.to_datetime(df4["Timestamp"])
df5["Timestamp"] = pd.to_datetime(df5["Timestamp"])
df6["Timestamp"] = pd.to_datetime(df6["Timestamp"])

df3["Label"] = df5.apply(test, axis=1)
df4["Label"] = df5.apply(test, axis=1)
df6["Label"] = df5.apply(test, axis=1)

df3_groupby = df3.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df4_groupby = df4.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df5_groupby = df5.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()
df6_groupby = df6.groupby(pd.Grouper(key="Timestamp", axis=0, freq="D")).mean()

df3_groupby.reset_index(inplace=True)
df4_groupby.reset_index(inplace=True)
df5_groupby.reset_index(inplace=True)
df6_groupby.reset_index(inplace=True)

df3_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df4_groupby["Label"] = df5_groupby.apply(add_label, axis=1)
df6_groupby["Label"] = df5_groupby.apply(add_label, axis=1)

# %%
sns.lineplot(x="Timestamp", y="Value", data=df3_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df4_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>

# %%
sns.lineplot(x="Timestamp", y="Value", data=df6_groupby, hue="Label")
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Value'>
