# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import plotly.express as px
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (10, 8)
mpl.rcParams['axes.grid'] = False
sns.set(rc={'figure.figsize':(15,15)})

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("E1 2016_2017.csv")
df
# Out:
#           DMA        Date      Time   Flow Flow Validity Code
# 0           5  01/04/2016  00:00:00  2.667                  V
# 1           5  01/04/2016  00:15:00  2.678                  V
# 2           5  01/04/2016  00:30:00  2.689                  V
# 3           5  01/04/2016  00:45:00  2.656                  V
# 4           5  01/04/2016  01:00:00  2.722                  V
# ...       ...         ...       ...    ...                ...
# 4050351  2420  31/03/2017  22:45:00  4.889                  V
# 4050352  2420  31/03/2017  23:00:00  4.222                  V
# 4050353  2420  31/03/2017  23:15:00  4.333                  V
# 4050354  2420  31/03/2017  23:30:00  3.889                  V
# 4050355  2420  31/03/2017  23:45:00  3.444                  V
#
# [4050356 rows x 5 columns]

# %%
df["Flow Validity Code"].value_counts()
# Out:
# V    3893006
# M      93970
# I      63380
# Name: Flow Validity Code, dtype: int64

# %%
new_df = df[df["Flow Validity Code"]=="I"]

# %%
new_df["DMA"].unique()
# Out:
# array([   5,   50,   77,  133,  208,  220,  225,  251,  322,  347,  376,
#         442,  457,  512,  516,  611,  686,  708,  726,  744,  776,  790,
#         794,  798,  820,  831,  889,  914,  969,  987, 1024, 1030, 1039,
#        1055, 1071, 1099, 1227, 1269, 1364, 1374, 1394, 1400, 1480, 1503,
#        1535, 1588, 1625, 1650, 1668, 1674, 1693, 1699, 1738, 1818, 1844,
#        1913, 1951, 1965, 2024, 2136, 2191, 2240, 2261, 2285, 2400, 2420])

# %%
new_df[new_df["DMA"]==442]["Flow"].mean()
# Out:
# -1.1122631484210523

# %%
test = new_df[new_df["Flow"]>0]

# %%
df[df["DMA"]==50]["Flow Validity Code"].value_counts()
# Out:
# V    32968
# I     1093
# M      979
# Name: Flow Validity Code, dtype: int64

# %% [markdown]
# # DMA = 50

# %%
sub_df = df[df["DMA"]==50].copy()
sub_df
# Out:
#        DMA        Date      Time      Flow Flow Validity Code
# 51935   50  01/04/2016  00:00:00  6.456000                  V
# 51936   50  01/04/2016  00:15:00  5.778000                  V
# 51937   50  01/04/2016  00:30:00  5.266999                  V
# 51938   50  01/04/2016  00:45:00  4.855000                  V
# 51939   50  01/04/2016  01:00:00  5.100000                  V
# ...    ...         ...       ...       ...                ...
# 86970   50  31/03/2017  22:45:00  2.734000                  V
# 86971   50  31/03/2017  23:00:00  3.634000                  V
# 86972   50  31/03/2017  23:15:00  8.000999                  V
# 86973   50  31/03/2017  23:30:00  7.633000                  V
# 86974   50  31/03/2017  23:45:00  7.678000                  V
#
# [35040 rows x 5 columns]

# %%
sub_df["Date"] = sub_df["Date"] + " " + sub_df["Time"]

# %%
sub_df["Date"] = pd.to_datetime(sub_df["Date"])
sub_df.drop("Time", axis=1, inplace=True)
sub_df
# Out:
#        DMA                Date      Flow Flow Validity Code
# 51935   50 2016-01-04 00:00:00  6.456000                  V
# 51936   50 2016-01-04 00:15:00  5.778000                  V
# 51937   50 2016-01-04 00:30:00  5.266999                  V
# 51938   50 2016-01-04 00:45:00  4.855000                  V
# 51939   50 2016-01-04 01:00:00  5.100000                  V
# ...    ...                 ...       ...                ...
# 86970   50 2017-03-31 22:45:00  2.734000                  V
# 86971   50 2017-03-31 23:00:00  3.634000                  V
# 86972   50 2017-03-31 23:15:00  8.000999                  V
# 86973   50 2017-03-31 23:30:00  7.633000                  V
# 86974   50 2017-03-31 23:45:00  7.678000                  V
#
# [35040 rows x 4 columns]

# %%
sns.lineplot(x=sub_df['Date'], y=sub_df["Flow"], hue=sub_df["Flow Validity Code"])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Flow'>

# %% [markdown]
# # DMA = 77

# %%
sub_df = df[df["DMA"]==77].copy()
sub_df["Date"] = sub_df["Date"] + " " + sub_df["Time"]
sub_df["Date"] = pd.to_datetime(sub_df["Date"])
sub_df.drop("Time", axis=1, inplace=True)
sns.lineplot(x=sub_df['Date'], y=sub_df["Flow"], hue=sub_df["Flow Validity Code"])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Flow'>

# %% [markdown]
# # DMA = 133

# %%
sub_df = df[df["DMA"]==133].copy()
sub_df["Date"] = sub_df["Date"] + " " + sub_df["Time"]
sub_df["Date"] = pd.to_datetime(sub_df["Date"])
sub_df.drop("Time", axis=1, inplace=True)
sns.lineplot(x=sub_df['Date'], y=sub_df["Flow"], hue=sub_df["Flow Validity Code"], data=sub_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Flow'>

# %% [markdown]
# # DMA = 208

# %%
sub_df = df[df["DMA"]==208].copy()
sub_df["Date"] = sub_df["Date"] + " " + sub_df["Time"]
sub_df["Date"] = pd.to_datetime(sub_df["Date"])
sub_df.drop("Time", axis=1, inplace=True)
sns.lineplot(x=sub_df['Date'], y=sub_df["Flow"], hue=sub_df["Flow Validity Code"], data=sub_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Flow'>

# %% [markdown]
# # DMA = 322

# %%
sub_df = df[df["DMA"]==322].copy()
sub_df["Date"] = sub_df["Date"] + " " + sub_df["Time"]
sub_df["Date"] = pd.to_datetime(sub_df["Date"])
sub_df.drop("Time", axis=1, inplace=True)
sns.lineplot(x=sub_df['Date'], y=sub_df["Flow"], hue=sub_df["Flow Validity Code"], data=sub_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Flow'>

# %% [markdown]
# # DMA = 347

# %%
sub_df = df[df["DMA"]==347].copy()
sub_df["Date"] = sub_df["Date"] + " " + sub_df["Time"]
sub_df["Date"] = pd.to_datetime(sub_df["Date"])
sub_df.drop("Time", axis=1, inplace=True)
sns.lineplot(x=sub_df['Date'], y=sub_df["Flow"], hue=sub_df["Flow Validity Code"], data=sub_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Flow'>
